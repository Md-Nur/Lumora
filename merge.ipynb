# %%
import pandas as pd

# %%
df = pd.read_csv("data/ct_rate/dataset/radiology_text_reports/validation_reports.csv")
df.head()
# Out:
#            VolumeName ClinicalInformation_EN  \
# 0  valid_1_a_1.nii.gz             Not given.
# 1  valid_1_a_2.nii.gz             Not given.
# 2  valid_2_a_1.nii.gz             Not given.
# 3  valid_2_a_2.nii.gz             Not given.
# 4  valid_3_a_1.nii.gz             Not given.
#
#                                         Technique_EN  \
# 0  Non-contrast images were taken in the axial pl...
# 1  Non-contrast images were taken in the axial pl...
# 2  1.5 mm thick non-contrast sections were taken ...
# 3  1.5 mm thick non-contrast sections were taken ...
# 4  Non-contrast images were taken in the axial pl...
#
#                                          Findings_EN  \
# 0  Trachea, both main bronchi are open. Mediastin...
# 1  Trachea, both main bronchi are open. Mediastin...
# 2   As far as can be seen; A stable soft tissue m...
# 3   As far as can be seen; A stable soft tissue m...
# 4  Trachea was in the midline of both main bronch...
#
# ...

# %%
# combine Technique and Findings and Impressions into a single column
df["report"] = df["Technique_EN"] + " " + df["Findings_EN"] + " " + df["Impressions_EN"]
df.head()
# Out:
#            VolumeName ClinicalInformation_EN  \
# 0  valid_1_a_1.nii.gz             Not given.
# 1  valid_1_a_2.nii.gz             Not given.
# 2  valid_2_a_1.nii.gz             Not given.
# 3  valid_2_a_2.nii.gz             Not given.
# 4  valid_3_a_1.nii.gz             Not given.
#
#                                         Technique_EN  \
# 0  Non-contrast images were taken in the axial pl...
# 1  Non-contrast images were taken in the axial pl...
# 2  1.5 mm thick non-contrast sections were taken ...
# 3  1.5 mm thick non-contrast sections were taken ...
# 4  Non-contrast images were taken in the axial pl...
#
#                                          Findings_EN  \
# 0  Trachea, both main bronchi are open. Mediastin...
# 1  Trachea, both main bronchi are open. Mediastin...
# 2   As far as can be seen; A stable soft tissue m...
# 3   As far as can be seen; A stable soft tissue m...
# 4  Trachea was in the midline of both main bronch...
#
# ...

# %%
df[["report"]].to_csv("data/ct_rate/dataset/radiology_text_reports/validation_reports_combined.csv", index=False)
